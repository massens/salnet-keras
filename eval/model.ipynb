# %%
import sys
sys.path.append('/root/sharedfolder/salnet_keras/')
import model_salnet_keras as salnet
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
reload(salnet)
# Out:
# <module 'model_salnet_keras' from '/root/sharedfolder/salnet_keras/model_salnet_keras.pyc'>

# %%
model = salnet.get_model()
(X_train, Y_train), val = salnet.load_datasets()
# Out:
# (9000, 3, 240, 320) (9000, 1, 240, 320)
# (1000, 3, 240, 320) (1000, 1, 240, 320)

# %%
model.load_weights('/root/sharedfolder/salnet_keras/output/model1_8/model.34.weights')

# %%
#preds = model.predict(X_train[:10])
plt.imshow(Y_train[1,0,:,:])

# %%
plt.imshow(preds[1,0,:,:])

# %%
preds
# Out:
# array([[[[ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          ...,
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5],
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5],
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5]]],
#
#
#        [[[ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          ...,
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5],
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5],
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5]]],
#
#
#        [[[ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          ...,
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5],
#          [ 0. ,  0. ,  0. , ...,  0.5,  0.5,  0.5],
# ...

# %%
plt.imshow(Y_train[0,0,:,:])
np.sum(Y_train[0,0,:,:])
# Out:
# 17360.928

# %%
preds = generator.predict(X_train[:10])
preds.shape
# Out:
# (10, 1, 240, 320)

# %%
preds
# Out:
# array([[[[ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          ...,
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5]]],
#
#
#        [[[ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          ...,
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5]]],
#
#
#        [[[ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          ...,
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
#          [ 0.5,  0.5,  0.5, ...,  0.5,  0.5,  0.5],
# ...

# %%
plt.imshow(preds[0,0,:,:])
